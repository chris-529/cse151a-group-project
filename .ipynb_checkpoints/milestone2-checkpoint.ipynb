# %%
# Environment requirements
# !pip3 install kagglehub
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip3 install --upgrade pip

# %%
# Load data

# %%
import numpy as np
import pandas as pd

import kagglehub

# Download latest version
path = kagglehub.dataset_download("waqi786/remote-work-and-mental-health")

df = pd.read_csv(f"{path}/Impact_of_Remote_Work_on_Mental_Health.csv")
# Out:
#      Employee_ID  Age      Gender           Job_Role    Industry  \
# 0        EMP0001   32  Non-binary                 HR  Healthcare
# 1        EMP0002   40      Female     Data Scientist          IT
# 2        EMP0003   59  Non-binary  Software Engineer   Education
# 3        EMP0004   27        Male  Software Engineer     Finance
# 4        EMP0005   49        Male              Sales  Consulting
# ...          ...  ...         ...                ...         ...
# 4995     EMP4996   32        Male              Sales  Consulting
# 4996     EMP4997   39      Female              Sales  Healthcare
# 4997     EMP4998   42      Female              Sales  Healthcare
# 4998     EMP4999   27      Female              Sales  Healthcare
# 4999     EMP5000   29        Male                 HR          IT
#
#       Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 0                      13        Hybrid                     47
# ...

# %%
# Data exploration
# evaluate your data, # of observations, details about your data distributions, scales, missing data, column descriptions

# %% [markdown]
# # Number of observations: 5000 observations
# # Missing data: We have 2 columns (features) that have null values. The feature "Mental_Health_Condition" and "Physical_Activity" are the features with null values. We will interpret the null values in "Mental_Health_Condition" to mean that they do not have any underlying mental health condition.
#
# # Column descriptions:
#
# ## Numerical columns:
# - Age
# - Years_Of_Experience
# - Hours_Worked_Per_Week
# - Number_of_Virtual_Meetings
# - Wolf_Life_Balance_Rating (rating from 1-5)
# - Social_Isolation_Rating (rating from 1-5)
# - Company_Support_for_Remote_Work (rating from 1-5)
#
# ## Categorical columns:
# - Gender
# - Job_Role
# - Industry
# - Work_Location
# - Stress_Level
# - Mental_Health_Condition
# - Access_to_Mental_Health_Resources
# - Productivity_Change
# - Satisfaction_with_Remote_Work
# - Physical_Activity
# - Sleep_Quality
# - Region

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Employee_ID                        5000 non-null   object
#  1   Age                                5000 non-null   int64
#  2   Gender                             5000 non-null   object
#  3   Job_Role                           5000 non-null   object
#  4   Industry                           5000 non-null   object
#  5   Years_of_Experience                5000 non-null   int64
#  6   Work_Location                      5000 non-null   object
#  7   Hours_Worked_Per_Week              5000 non-null   int64
#  8   Number_of_Virtual_Meetings         5000 non-null   int64
#  9   Work_Life_Balance_Rating           5000 non-null   int64
#  10  Stress_Level                       5000 non-null   object
# ...

# %% [markdown]
# # Below are the quartiles, mean, std, and min/max for our dataset for each feature

# %%
df.describe().round(2)
# Out:
#           Age  Years_of_Experience  Hours_Worked_Per_Week  \
# count  5000.0              5000.00                5000.00
# mean     41.0                17.81                  39.61
# std      11.3                10.02                  11.86
# min      22.0                 1.00                  20.00
# 25%      31.0                 9.00                  29.00
# 50%      41.0                18.00                  40.00
# 75%      51.0                26.00                  50.00
# max      60.0                35.00                  60.00
#
#        Number_of_Virtual_Meetings  Work_Life_Balance_Rating  \
# count                     5000.00                   5000.00
# mean                         7.56                      2.98
# std                          4.64                      1.41
# min                          0.00                      1.00
# 25%                          4.00                      2.00
# 50%                          8.00                      3.00
# ...

# %%
# Plot data (tabular, so scatters)

# %%
# How will we preprocess our data?: This is all explained inside of README.md (drop id)
